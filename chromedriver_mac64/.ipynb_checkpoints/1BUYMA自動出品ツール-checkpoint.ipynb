# %%
from selenium import webdriver
from selenium.webdriver.chrome import service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from PIL import Image
from time import sleep
import os
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.select import Select

browser = webdriver.Chrome()
url = ("https://www.buyma.com/loginredirect/")
browser.get(url)

#アカウントログイン
elem_username = browser.find_element(By.ID, "txtLoginId")
elem_username.send_keys("nanana114456@gmail.com")
elem_pass = browser.find_element(By.ID, "txtLoginPass")
elem_pass.send_keys("nananax1122")

sleep(1)
elem_login_btn = browser.find_element(By.ID, "login_do")
elem_login_btn.click()


sleep(6)
#出品登録ページに遷移
my_page = browser.find_element(By.CLASS_NAME, "user_name")
my_page.click()
sleep(5)
new_item_page=("https://www.buyma.com/my/sell/new?tab=b")
browser.get(new_item_page)

# %%
wait = WebDriverWait(browser, 10)
#スプレッドシートの読み込み
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('/Users/nakaosatoshi/Desktop/python/credentials.json', scope)
client = gspread.authorize(creds)
sheet = client.open_by_key('164llLtJGZzcGlOrw7CfYEPBspBeOOtB5HRUAooC1UQg')


#商品タイトル
title_input = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'bmm-c-text-field')))
title_input.send_keys(sheet.worksheet('シート').cell(8, 4).value)


title_input = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'bmm-c-textarea')))
title_input.send_keys(sheet.worksheet('シート').cell(8, 4).value)

sleep(4)

#(第一階層)
categoly_select = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-control')))
categoly_select.click()

# カテゴリーを選択
selected_category_1 = sheet.worksheet('シート').cell(8, 4).value
options = browser.find_elements(By.CSS_SELECTOR, ".Select-option[aria-label='{}']".format(selected_category_1))
options[0].click()

#(第二階層)
categoly_select = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-placeholder')))
sleep(3)
categoly_select.click()

# カテゴリーを選択
selected_category_2 = sheet.worksheet('シート').cell(9, 4).value
options = browser.find_elements(By.CSS_SELECTOR, ".Select-option[aria-label='{}']".format(selected_category_2))
options[0].click()

#(第三階層)
categoly_select = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-placeholder')))
sleep(3)
categoly_select.click()

# カテゴリーを選択
selected_category_2 = sheet.worksheet('シート').cell(10, 4).value
options = browser.find_elements(By.CSS_SELECTOR, ".Select-option[aria-label='{}']".format(selected_category_2))
options[0].click()

# %%
#(第一階層)
categoly_select = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-control')))
categoly_select.click()

# カテゴリーを選択
selected_category_1 = sheet.worksheet('シート').cell(8, 4).value
options = browser.find_elements(By.CSS_SELECTOR, ".Select-option[aria-label='{}']".format(selected_category_1))
options[0].click()

#(第二階層)
categoly_select = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-placeholder')))
sleep(3)
categoly_select.click()

# カテゴリーを選択
selected_category_2 = sheet.worksheet('シート').cell(9, 4).value
options = browser.find_elements(By.CSS_SELECTOR, ".Select-option[aria-label='{}']".format(selected_category_2))
options[0].click()

# %%
#カテゴリーセレクト
categoly_select = WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-control')))
categoly_select.click()

# "カテゴリ1" を選択する
found = False
while not found:
    options = browser.find_elements(By.CSS_SELECTOR, ".Select-option")
    for option in options:
        if option.get_attribute("aria-label") == (sheet.worksheet('シート').cell(8, 4).value):
            option.click()
            found = True
            break
    else:
        continue
    break

# "リストを選択" ボタンをクリックする
categoly_select = WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-placeholder')))
sleep(3)
categoly_select.click()

# "カテゴリ2" を選択する
found = False
while not found:
    options = browser.find_elements(By.CSS_SELECTOR, ".Select-option")
    for option in options:
        if option.get_attribute("aria-label") == (sheet.worksheet('シート').cell(9, 4).value):
            option.click()
            found = True
            break
    else:
        continue
    break
    
# "リストを選択" ボタンをクリックする
categoly_select = WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-placeholder')))
sleep(3)
categoly_select.click()

# "カテゴリ３" を選択する    
categoly_select = WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CLASS_NAME, 'Select-placeholder')))
sleep(3)
categoly_select.click()    
    
found = False
while not found:
    options = browser.find_elements(By.CSS_SELECTOR, ".Select-option")
    for option in options:
        if option.get_attribute("aria-label") == (sheet.worksheet('シート').cell(10, 4).value):
            option.click()
            found = True
            break
    else:
        continue
    break
